# %% [markdown]
# # openbb_akshare
#
# Check openbb_akshare version

# %%
import os
from dotenv import load_dotenv
from openbb import obb

if 'info' in obb.reference:
    obj = obb.reference["info"]["extensions"]["openbb_provider_extension"]
    print([item for item in obj if "akshare" in item])

symbols = "601919,600519,000001,00300"
symbols_a = "601919,600519,000001,600325,600028,600036,430047"
symbol_a = "600325"
symbol_hk = "01658"
provider = "akshare"
start_date="2025-09-08"
end_date="2025-12-31"

load_dotenv() 
akshare_api_key = os.environ.get("AKSHARE_API_KEY")
if akshare_api_key is None:
    raise ValueError("AKSHARE_API_KEY environment variable not set.")
# Out:
# ['akshare@1.2.0']

# %% [markdown]
# ## 1. 股票相关模型 (Equity Models)
# ### 1.1 Equity Historical Price (股票历史价格)

# %%
obb.equity.price.historical(symbol=symbol_a, provider=provider, use_cache=True, start_date=start_date, end_date=end_date).to_dataframe().tail()
# Out:
# 2026-04-22 11:15:09,341 - openbb_akshare.utils.helpers - INFO - Getting equity 600325 historical data from cache...
#             open  high   low  close  volume       amount  change  \
# date
# 2025-12-25  4.35  4.37  4.31   4.34  178823   77532672.0    0.01
# 2025-12-26  4.33  4.35  4.29   4.30  234915  101547573.0   -0.04
# 2025-12-29  4.30  4.32  4.23   4.24  311909  132894430.0   -0.06
# 2025-12-30  4.23  4.24  4.18   4.19  242283  102005642.0   -0.05
# 2025-12-31  4.21  4.23  4.17   4.22  198082   83381305.0    0.03
#
#             change_percent
# date
# 2025-12-25            0.23
# 2025-12-26           -0.92
# 2025-12-29           -1.40
# 2025-12-30           -1.18
# 2025-12-31            0.72

# %% [markdown]
# ### 1.2 Equity Quote (股票实时报价)

# %%
obb.equity.price.quote(symbols, provider=provider).to_dataframe().head()
# Out:
# 2026-02-04 15:57:13,439 - openbb_akshare.models.equity_quote - INFO - Fetching data for symbol: SH601919
# 2026-02-04 15:57:14,431 - openbb_akshare.models.equity_quote - INFO - Fetching data for symbol: SH600519
# 2026-02-04 15:57:15,295 - openbb_akshare.models.equity_quote - INFO - Fetching data for symbol: SZ000001
# 2026-02-04 15:57:16,209 - openbb_akshare.models.equity_quote - INFO - Fetching data for symbol: 00300
#      symbol  name exchange     open     high      low     volume  prev_close  \
# 0  SH601919  中远海控       SH    14.24    14.59    14.21  136894143       14.22
# 1  SH600519  贵州茅台       SH  1485.00  1533.27  1474.00   10912293     1474.92
# 2  SZ000001  平安银行       SZ    10.85    10.98    10.84   69541547       10.84
# 3     00300  美的集团       HK    87.40    89.45    86.45    3066824       87.05
#
#    change_percent  52_week_high  ...  dividend_yield_ttm  currency  \
# 0            2.46       16.0979  ...              11.036       CNY
# 1            3.40     1598.8965  ...               3.391       CNY
# 2            1.20       13.0581  ...               5.451       CNY
# 3            1.55       92.1500  ...               5.100       HKD
#
#    book_value_per_share  pe_ratio_static      turnover  pb_ratio  limit_up  \
# 0               14.9931           4.5440  1.982236e+09    0.9720     15.64
# 1              205.2831          22.1470  1.644435e+10    7.4290   1622.41
# 2               23.0800           4.7830  7.601077e+08    0.4750     11.92
# 3               32.0769          16.4273  2.714305e+08    2.7804       NaN
#
#    pe_ratio_ttm                 time  ps_ratio
# 0        5.8640  2026-02-04 15:00:00       NaN
# 1       21.2130  2026-02-04 15:00:00       NaN
# 2        4.9370  2026-02-04 15:04:45       NaN
# 3       14.3002  2026-02-04 15:57:03     1.192
#
# [4 rows x 38 columns]

# %% [markdown]
# ### 1.4 Equity Search (股票搜索)

# %%
obb.equity.search(query="", provider=provider).to_dataframe()
# Out:
# 2026-03-10 16:59:36,686 - openbb_akshare.utils.ak_equity_search - INFO - Loading symbols from openbb_akshare cache...
#       symbol         name exchange
# 0     000001         平安银行     SZSE
# 1     000002        万  科Ａ     SZSE
# 2     000004        *ST国华     SZSE
# 3     000006         深振业Ａ     SZSE
# 4     000007          全新好     SZSE
# ...      ...          ...      ...
# 9990   00059         天誉置业     HKEX
# 9991   00039        中国北大荒     HKEX
# 9992   00033  INTL GENIUS     HKEX
# 9993   00009         金奥国际     HKEX
# 9994   00007       智富资源投资     HKEX
#
# [9995 rows x 3 columns]

# %% [markdown]
# ### 1.5 Equity Screener (股票筛选器)
# 因为下载数据较多，这个功能容易出现数据下载问题

# %%
obb.equity.screener(provider=provider).to_dataframe().head()
# Out:
# 2026-02-04 15:57:27,363 - openbb_akshare.utils.fetch_quote - INFO - Generating new data...
# ---------------------------------------------------------------------------
# OpenBBError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 obb.equity.screener(provider=provider).to_dataframe().head()
#
# File c:\src\openbb\openbb_akshare\.venv\Lib\site-packages\openbb_core\app\static\utils\decorators.py:102, in exception_handler.<locals>.wrapper(*f_args, **f_kwargs)
#     100         raise OpenBBError(f"\n[Error] -> {e}").with_traceback(tb) from None
#     101     if isinstance(e, Exception):
# --> 102         raise OpenBBError(
#     103             f"\n[Unexpected Error] -> {e.__class__.__name__} -> {e}"
#     104         ).with_traceback(tb) from None
#     106 return None
#
# File c:\src\openbb\openbb_akshare\.venv\Lib\site-packages\requests\adapters.py:671, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     668     raise RetryError(e, request=request)
#     670 if isinstance(e.reason, _ProxyError):
# --> 671     raise ProxyError(e, request=request)
#     673 if isinstance(e.reason, _SSLError):
#     674     # This branch is for urllib3 v1.22 and later.
#     675     raise SSLError(e, request=request)
#
# OpenBBError:
# [Unexpected Error] -> ProxyError -> HTTPSConnectionPool(host='72.push2.eastmoney.com', port=443): Max retries exceeded with url: /api/qt/clist/get?pn=1&pz=100&po=1&np=1&ut=bd1d9ddb04089700cf9c27f6f7426281&fltt=2&invt=2&fid=f12&fs=m%3A128+t%3A3%2Cm%3A128+t%3A4%2Cm%3A128+t%3A1%2Cm%3A128+t%3A2&fields=f1%2Cf2%2Cf3%2Cf4%2Cf5%2Cf6%2Cf7%2Cf8%2Cf9%2Cf10%2Cf12%2Cf13%2Cf14%2Cf15%2Cf16%2Cf17%2Cf18%2Cf20%2Cf21%2Cf23%2Cf24%2Cf25%2Cf22%2Cf11%2Cf62%2Cf128%2Cf136%2Cf115%2Cf152 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))

# %% [markdown]
# ### 1.6 Equity Profile (股权资料)

# %%
obb.equity.profile(symbol="00005", provider='akshare', use_cache=True).to_dataframe().tail()
# Out:
#      symbol               name  ceo          company_url  \
# 0  00005.HK  HSBC Holdings plc  利伯特  http://www.hsbc.com
#
#                                     business_address mailing_address  \
# 0  42nd Floor, 8 Canada Square, London United Kin...     香港中环皇后大道中1号
#
#   business_phone_no  employees industry_category      公司名称  \
# 0   (852) 2822-1111          0               3.0  汇丰控股有限公司
#
#                                                 公司简介  \
# 0      滙丰总部设於伦敦,是世界上规模最大的银行及金融服务机构之一。滙丰集团之国际网络横跨全...
#
#                                          主要范围        上市日期 org_short_name_cn  \
# 0      提供全面之银行及有关之金融服务。国际网络遍布亚太区、欧洲、美洲、中东及非洲。  1988-12-29
#
#   org_short_name_en       org_id  actual_issue_vol  reg_asset currency  \
# 0                    200077073.0                 0        0.0      HKD
#
#                  成立日期
# 0 1958-12-31 16:00:00

# %%
import akshare as ak

ak.stock.cons.xq_a_token = "d54a0f75b8fedddbb1d04f0e5ede2e797237ec84"
stock_individual_basic_info_hk_xq_df = ak.stock_individual_basic_info_hk_xq(symbol="00386")
print(stock_individual_basic_info_hk_xq_df)
# Out:
#            item                                              value
# 0       comunic                                        200001230.0
# 1     comcnname                                       中国石油化工股份有限公司
# 2     comenname             China Petroleum & Chemical Corporation
# 3       incdate                                     951408000000.0
# 4        rgiofc                                  中国北京市朝阳区朝阳门北大街22号
# 5    hofclctmbu                               香港湾仔港湾道1号会展广场办公大楼20楼
# 6      chairman                                                侯启军
# 7           mbu      本公司的主要业务包括:在中国勘探、开发及生产原油及天然气;管输原油、天然气;炼油;以...
# 8       comintr      中国石油化工股份有限公司(以下简称“中国石化”)是一家上中下游一体化、石油石化主业突...
# 9     refccomty                                                1.0
# 10     numtissh                                               None
# 11         ispr                                               None
# 12         nrfd                                               None
# 13  nation_name                                                 中国
# 14          tel                                       010-59960028
# 15          fax                                       010-59960386
# 16        email                                     ir@sinopec.com
# 17     web_site                             http://www.sinopec.com
# 18    lsdateipo                                     971884800000.0
# 19   mainholder                                       中国石油化工集团有限公司

# %% [markdown]
# ### 1.7 Historical Dividends (历史分红)

# %%
obb.equity.fundamental.dividends(symbol=symbol_a, provider=provider, use_cache=False).to_dataframe().head()
# Out:
# 2026-02-04 15:57:47,568 - openbb_akshare.models.historical_dividends - INFO - Transformed historical dividends completed.
#   ex_dividend_date  amount    description record_date report_date
# 0       2005-04-18    0.10      10派1元(含税)  2005-04-15  2005-04-12
# 1       2005-10-28    0.00         10转增3股  2005-10-27  2005-10-22
# 2       2006-04-07    0.10      10派1元(含税)  2006-04-06  2006-04-01
# 3       2008-02-27    0.10  10转10股派1元(含税)  2008-02-26  2008-02-21
# 4       2009-04-02    0.11    10派1.1元(含税)  2009-04-01  2009-03-26

# %% [markdown]
# ## 2. 财务报表模型 (Financial Statement Models)
# ### 2.1 Balance Sheet (资产负债表)

# %%
obb.equity.fundamental.balance(symbol=symbol_hk, period="annual", limit=5,provider=provider).to_dataframe().head()
# Out:
# 2026-02-04 15:57:51,214 - openbb_akshare.models.balance_sheet - INFO - Fetching balance sheet data for 01658 with limit 5 and use_cache=True
# 2026-02-04 15:57:51,217 - mysharelib.blob_cache - INFO - Loaded cached annual data with length 4 and limit is 5
# 2026-02-04 15:57:51,218 - mysharelib.blob_cache - INFO - Generating new annual data for 01658...
# 2026-02-04 15:57:51,235 - openbb_akshare.models.balance_sheet - INFO - Getting balance sheet data for 01658 with limit 5
# 2026-02-04 15:57:51,236 - openbb_akshare.utils.ak_balance_sheet - INFO - Fetching HK balance sheet for 01658 with limit 5 and period annual
#   period_ending           总资产      买入返售金融资产  以公允价值计量的金融资产           优先股  \
# 0    2024-12-31  1.708491e+13  2.298420e+11  6.004127e+12           NaN
# 1    2023-12-31  1.572663e+13  4.095260e+11  5.387588e+12           NaN
# 2    2022-12-31  1.406728e+13  2.298700e+11  4.958899e+12           NaN
# 3    2021-12-31  1.258787e+13  2.652290e+11  4.348620e+12  4.786900e+10
#
#      保留溢利(累计亏损)           公积金          其他储备      卖出回购金融资产       向中央银行借款  ...  \
# 0  2.633430e+11  1.626810e+11  3.044980e+11  1.945240e+11  2.613800e+10  ...
# 1  2.493040e+11  1.626820e+11  2.737400e+11  2.733640e+11  3.383500e+10  ...
# 2  2.251960e+11  1.244790e+11  2.421800e+11  1.836460e+11  2.481500e+10  ...
# 3  1.988400e+11  1.254860e+11  2.195260e+11  3.464300e+10  1.731600e+10  ...
#
#       衍生金融工具-负债     衍生金融工具-资产        负债其他项目        资产其他项目      递延税项负债  \
# 0  7.199000e+09  6.661000e+09  1.127320e+11  1.127720e+11  57000000.0
# 1  3.595000e+09  2.154000e+09  8.652200e+10  6.925800e+10   4000000.0
# 2  2.465000e+09  1.905000e+09  8.979900e+10  5.180900e+10  11000000.0
# 3  5.176000e+09  6.053000e+09  9.803800e+10  5.945100e+10  11000000.0
#
#          递延税项资产  银行同业及其他金融机构存款(负债)  银行同业及其他金融机构存款(资产)       非控股股东权益  \
# 0  6.118500e+10       1.355990e+11       2.624760e+11  1.980000e+09
# 1  6.250800e+10       9.530300e+10       1.892160e+11  1.743000e+09
# 2  6.395500e+10       7.877000e+10       1.614220e+11  1.589000e+09
# 3  5.631900e+10       1.548090e+11       9.078200e+10  1.458000e+09
#
#           非运算项目
# 0  1.231635e+12
# 1  1.126602e+12
# 2  8.258140e+11
# 3  7.955490e+11
#
# [4 rows x 35 columns]

# %% [markdown]
# ### 2.2 Income Statement (利润表)

# %%
obb.equity.fundamental.income(symbol=symbol_hk, provider=provider).to_dataframe()
# Out:
# 2026-02-04 15:58:07,066 - openbb_akshare.models.income_statement - INFO - Fetching income statement data for 01658 with limit 5 and use_cache=True
# 2026-02-04 15:58:07,070 - mysharelib.blob_cache - INFO - Loaded cached annual data with length 2 and limit is 5
# 2026-02-04 15:58:07,070 - mysharelib.blob_cache - INFO - Generating new annual data for 01658...
# 2026-02-04 15:58:07,071 - openbb_akshare.models.income_statement - INFO - Getting income statement data for 01658 with limit 5
# 2026-02-04 15:58:07,072 - openbb_akshare.utils.ak_income_statement - INFO - Fetching HK income statement for 01658 with limit 5 and period annual
#   period_ending         交易净收益        全面收益总额        其他全面收益    其他全面收益其他项目  \
# 0    2024-12-31  4.185000e+09  9.190300e+10  5.187000e+09  5.187000e+09
# 1    2023-12-31  4.460000e+09  8.671200e+10  2.880000e+08  2.880000e+08
# 2    2022-12-31  3.673000e+09  7.870500e+10 -6.650000e+09 -6.650000e+09
# 3    2021-12-31  3.286000e+09  8.586100e+10  9.329000e+09  9.329000e+09
#
#          其他经营收入         净利息收入         减值及拨备          利息支出          利息收入  ...  \
# 0  9.010000e+08  2.861230e+11  2.844500e+10  2.221200e+11  5.082430e+11  ...
# 1  1.418000e+09  2.818030e+11  2.617100e+10  2.165240e+11  4.983270e+11  ...
# 2  7.209000e+09  2.735930e+11  3.534700e+10  2.006470e+11  4.742400e+11  ...
# 3  7.450000e+08  2.693820e+11  4.665800e+10  1.821850e+11  4.515670e+11  ...
#
#          经营支出总额      经营收入其他项目        经营收入总额          经营溢利        股东应占溢利  \
# 0  2.260960e+11  2.500000e+07  3.491330e+11  9.459200e+10  8.647900e+10
# 1  2.251420e+11  1.800000e+07  3.429120e+11  9.159900e+10  8.627000e+10
# 2  2.086800e+11  2.843700e+10  3.353910e+11  9.136400e+10  8.522400e+10
# 3  1.909950e+11           NaN  3.191070e+11  8.145400e+10  7.617000e+10
#
#            营运支出         除税前溢利         除税后溢利  非控股权益应占全面收益总额         非运算项目
# 0  2.260960e+11  9.459200e+10  8.671600e+10    237000000.0  5.134300e+11
# 1  2.251420e+11  9.159900e+10  8.642400e+10    154000000.0  4.986150e+11
# 2  2.086800e+11  9.136400e+10  8.535500e+10    131000000.0  5.026740e+11
# 3  1.909950e+11  8.145400e+10  7.653200e+10    362000000.0  4.608960e+11
#
# [4 rows x 30 columns]

# %% [markdown]
# ### 2.3 Cash Flow Statement (现金流量表)

# %%
obb.equity.fundamental.cash(symbol=symbol_hk, provider=provider).to_dataframe().head()
# Out:
# 2026-02-04 15:58:19,564 - openbb_akshare.models.cash_flow - INFO - Fetching cash flow data for 01658 with limit 5 and use_cache=True
# 2026-02-04 15:58:19,567 - mysharelib.blob_cache - INFO - Loaded cached annual data with length 3 and limit is 5
# 2026-02-04 15:58:19,568 - mysharelib.blob_cache - INFO - Generating new annual data for 01658...
# 2026-02-04 15:58:19,585 - openbb_akshare.models.cash_flow - INFO - Getting cash flow data for 01658 with limit 5
# 2026-02-04 15:58:19,586 - openbb_akshare.utils.ak_cash_flow - INFO - Fetching HK cash flow for 01658 with limit 5 and period annual
#   period_ending          偿还借款        偿还融资租赁   减:出售资产之溢利        减:利息收入  \
# 0    2024-12-31  2.611600e+11  3.923000e+09  19000000.0  1.417370e+11
# 1    2023-12-31  3.351000e+11  3.934000e+09 -10000000.0  1.390810e+11
# 2    2022-12-31  2.000000e+10  3.895000e+09   1000000.0  1.284240e+11
# 3    2021-12-31  4.265000e+10  4.012000e+09 -32000000.0  1.276770e+11
#
#    减:应占附属公司溢利        减:投资收益        减:汇兑收益       加:减值及拨备        加:利息支出  ...  \
# 0  25000000.0  3.261700e+10  1.271000e+09  2.844500e+10  5.471000e+09  ...
# 1  18000000.0  2.696100e+10  2.520000e+08  2.617100e+10  7.137000e+09  ...
# 2   3000000.0  2.247900e+10  4.724000e+09  3.534700e+10  3.486000e+09  ...
# 3         NaN  2.368700e+10 -2.432000e+09  4.665800e+10  2.586000e+09  ...
#
#          经营产生现金    营运资本变动其他项目   营运资金变动前经营溢利      融资业务其他项目      融资业务现金净额  \
# 0  4.010690e+11 -5.019500e+10 -3.577500e+10           NaN -3.077800e+10
# 1  2.757960e+11  1.128410e+11 -2.926600e+10           NaN  1.922470e+11
# 2  4.875780e+11  1.672100e+11 -1.402100e+10 -5.127300e+10 -3.773700e+10
# 3  1.269000e+11 -1.265430e+11 -9.165000e+09           NaN  5.226300e+10
#
#         融资前现金净额        购建固定资产   贷款和垫款(增加)减少   除税前溢利(业务利润)         非运算项目
# 0 -8.312300e+10  2.035000e+10 -8.037780e+11  9.459200e+10  6.339380e+11
# 1  2.090900e+10  1.296300e+10 -9.506910e+11  9.159900e+10  5.072100e+11
# 2 -3.659300e+10  1.240200e+10 -7.693400e+11  9.136400e+10  1.851730e+11
# 3 -7.336000e+10  1.385300e+10 -7.564880e+11  8.145400e+10  3.503260e+11
#
# [4 rows x 36 columns]

# %% [markdown]
# ### 2.4 Key Metrics (关键指标)

# %%
obb.equity.fundamental.metrics(symbol=symbol_a, provider=provider).to_dataframe().head()
# Out:
#    symbol period_ending fiscal_period    market_cap       股票代码  证券简称  \
# 0  600325    2025-09-30       2025三季报  1.161408e+10  600325.SH  华发股份
#
#   基本每股收益(元) 扣非每股收益(元) 稀释每股收益(元) 每股净资产(元)  ...        流通股本(股) pe_ratio  \
# 0     0.037       N/A     0.040    6.897  ...  2,752,152,116   85.144
#
#   市盈率(TTM)  市盈率(静)    市净率 52周最低   52周最高 股息(TTM) 股息率(TTM)                 发行日期
# 0  -41.213  12.209  0.612  4.17  5.8544   0.124    2.938  2004-02-25 00:00:00
#
# [1 rows x 30 columns]

# %% [markdown]
# ## 3. 市场分析模型 (Market Analysis Models)
# ### 3.1 Company News (公司新闻)

# %%
obb.news.company(symbol_a, provider=provider).to_dataframe().head()
# Out:
#                                                 title  \
# date
# 2026-01-30 20:22:06            华发股份预计2025年亏损70亿元至90亿元
# 2026-01-30 21:06:38            华发股份预计2025年净亏损70亿—90亿元
# 2026-01-31 07:05:20  华金证券党委书记、总裁燕文波： 坚守功能性定位 打造差异化竞争力
# 2026-01-31 07:50:42     华发股份：融资净买入359.82万元，融资余额6.92亿元
# 2026-01-31 11:26:58                   华发股份：加快转型应对行业调整
#
#                                                                    url
# date
# 2026-01-30 20:22:06  http://finance.eastmoney.com/a/202601303637262...
# 2026-01-30 21:06:38  http://finance.eastmoney.com/a/202601303637299...
# 2026-01-31 07:05:20  http://finance.eastmoney.com/a/202601313637474...
# 2026-01-31 07:50:42  http://stock.eastmoney.com/a/20260131363762486...
# 2026-01-31 11:26:58  http://finance.eastmoney.com/a/202601313637734...

# %% [markdown]
# ### 3.2 Business Analysis (业务分析)

# %%
obb.akshare.business_analysis(symbol=symbol_a, provider=provider).to_dataframe().head()
# Out:
#       symbol report_date main_composition category_type  main_revenue  \
# 0  600325.SS  2025-09-30            房地产开发         按行业分类  4.688954e+10
# 1  600325.SS  2025-09-30             其他业务         按行业分类  4.860711e+09
# 2  600325.SS  2025-09-30            其中:住宅         按行业分类  4.401008e+10
# 3  600325.SS  2025-09-30         其中:商业、办公         按行业分类  2.879464e+09
# 4  600325.SS  2025-09-30            房地产开发         按产品分类  4.688954e+10
#
#    revenue_ratio     main_cost  cost_ratio   main_profit  profit_ratio  \
# 0       0.906074  3.986067e+10    0.898329  7.028870e+09      0.952651
# 1       0.093926  4.511359e+09    0.101671  3.493517e+08      0.047349
# 2       0.850432  3.705148e+10    0.835019  6.958600e+09      0.943127
# 3       0.055642  2.809193e+09    0.063310  7.027040e+07      0.009524
# 4       0.906074  3.986067e+10    0.898329  7.028870e+09      0.952651
#
#    gross_margin    code
# 0      0.149903  600325
# 1      0.071873  600325
# 2      0.158114  600325
# 3      0.024404  600325
# 4      0.149903  600325

# %% [markdown]
# ### 3.3 Price Performance (价格表现)

# %%
obb.equity.price.performance(symbol=symbols, provider=provider).to_dataframe().head()
# Out:
# 2026-02-04 11:11:22,584 - openbb_akshare.utils.helpers - INFO - Listing date for 601919 is 1182787200000.0.
# 2026-02-04 11:11:22,864 - openbb_akshare.utils.helpers - WARNING - Cache for 601919 is not up-to-date. Last date in cache: 2026-01-21, expected: 2026-02-03.
# 2026-02-04 11:11:26,514 - openbb_akshare.utils.helpers - INFO - Getting equity 601919 historical data from cache...
# 2026-02-04 11:11:26,804 - openbb_akshare.utils.helpers - INFO - Listing date for 600519 is 2001-08-26 16:00:00.
# 2026-02-04 11:11:27,246 - openbb_akshare.utils.helpers - WARNING - Cache for 600519 is not up-to-date. Last date in cache: NaT, expected: 2026-02-03.
# 2026-02-04 11:11:27,678 - openbb_akshare.utils.helpers - INFO - Getting equity 600519 historical data from cache...
# 2026-02-04 11:11:27,682 - openbb_akshare.utils.helpers - INFO - Listing date for 000001 is 670608000000.0.
# 2026-02-04 11:11:28,155 - openbb_akshare.utils.helpers - WARNING - Cache for 000001 is not up-to-date. Last date in cache: 2026-01-30, expected: 2026-02-03.
# 2026-02-04 11:11:28,631 - openbb_akshare.utils.helpers - INFO - Getting equity 000001 historical data from cache...
# 2026-02-04 11:11:28,922 - openbb_akshare.utils.helpers - INFO - Listing date for 00300 is 2024-09-16 16:00:00.
# 2026-02-04 11:11:29,634 - openbb_akshare.utils.helpers - WARNING - Cache for 00300 is not up-to-date. Last date in cache: 2026-01-23, expected: 2026-02-03.
# 2026-02-04 11:11:29,911 - openbb_akshare.utils.helpers - INFO - Getting equity 00300 historical data from cache...
#    symbol   one_day       wtd  one_week       mtd  one_month       qtd  \
# 0  601919  0.000049  0.000049 -0.000180  0.000049  -0.000501 -0.000456
# 1  600519  0.000336  0.000336  0.000259  0.000336   0.000328  0.000343
# 2  000001 -0.000018 -0.000018 -0.000109 -0.000018  -0.000711 -0.000574
# 3   00300  0.000152  0.000152  0.000093  0.000152  -0.000017 -0.000252
#
#    three_month  six_month       ytd  one_year  two_year  three_year  \
# 0    -0.000790  -0.000925 -0.000456  0.000092  0.004163    0.003315
# 1     0.000290   0.000207  0.000343  0.000507 -0.001200   -0.001783
# 2    -0.000615  -0.001187 -0.000574 -0.000466  0.001198   -0.002257
# 3     0.000104   0.000984 -0.000252  0.001982  0.004729    0.004729
#
#    four_year  five_year  ten_year       max
# 0  -0.001397   0.003415  0.016679 -0.001319
# 1  -0.002104  -0.003774  0.063595  0.404886
# 2  -0.003386  -0.005629  0.001073 -0.007788
# 3   0.004729   0.004729  0.004729  0.004729

# %% [markdown]
# ## 4. 基金相关模型 (Fund Models)
# ### 4.1 ETF Holdings (ETF 持仓)

# %%
obb.akshare.etf_holdings(symbol="159919", provider=provider).to_dataframe().head()

# %% [markdown]
# ### 4.2 ETF Search (ETF 搜索)

# %%
obb.etf.search(provider='akshare').to_dataframe().head()
# Out:
#    symbol        name
# 0  000001      华夏成长混合
# 1  000002  华夏成长混合(后端)
# 2  000003    中海可转债债券A
# 3  000004    中海可转债债券C
# 4  000005  嘉实增强信用定期债券

# %% [markdown]
# ### 4.3 Fund Holdings (基金持仓)

# %%
obb.akshare.fund_holdings(symbol="000011", provider=provider).to_dataframe().head()

# %% [markdown]
# ## 5. 货币相关模型 (Currency Models)
# ### 5.1 Currency Historical (货币历史价格)

# %%
obb.currency.price.historical(symbol='EURUSD', provider=provider).to_dataframe().head()
# Out:
#              open   high    low  close  change  symbol   name
# date
# 1999-01-01  1.174  1.180  1.166  1.180    0.00  EURUSD  欧元兑美元
# 1999-01-04  1.175  1.190  1.174  1.179    1.36  EURUSD  欧元兑美元
# 1999-01-05  1.179  1.184  1.177  1.182    0.59  EURUSD  欧元兑美元
# 1999-01-06  1.182  1.182  1.172  1.175    0.85  EURUSD  欧元兑美元
# 1999-01-07  1.175  1.177  1.156  1.166    1.79  EURUSD  欧元兑美元

# %% [markdown]
# ### 5.2 Currency Snapshots (货币快照)

# %%
obb.currency.snapshots(provider=provider).to_dataframe().head()
# Out:
# ---------------------------------------------------------------------------
# OpenBBError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 obb.currency.snapshots(provider=provider).to_dataframe().head()
#
# File c:\src\openbb\openbb_akshare\.venv\Lib\site-packages\openbb_core\app\static\utils\decorators.py:102, in exception_handler.<locals>.wrapper(*f_args, **f_kwargs)
#     100         raise OpenBBError(f"\n[Error] -> {e}").with_traceback(tb) from None
#     101     if isinstance(e, Exception):
# --> 102         raise OpenBBError(
#     103             f"\n[Unexpected Error] -> {e.__class__.__name__} -> {e}"
#     104         ).with_traceback(tb) from None
#     106 return None
#
# File c:\src\openbb\openbb_akshare\.venv\Lib\site-packages\requests\adapters.py:671, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     668     raise RetryError(e, request=request)
#     670 if isinstance(e.reason, _ProxyError):
# --> 671     raise ProxyError(e, request=request)
#     673 if isinstance(e.reason, _SSLError):
#     674     # This branch is for urllib3 v1.22 and later.
#     675     raise SSLError(e, request=request)
#
# OpenBBError:
# [Unexpected Error] -> ProxyError -> HTTPSConnectionPool(host='push2.eastmoney.com', port=443): Max retries exceeded with url: /api/qt/clist/get?np=1&fltt=2&invt=2&fs=m%3A119%2Cm%3A120%2Cm%3A133&fields=f12%2Cf13%2Cf14%2Cf1%2Cf2%2Cf4%2Cf3%2Cf152%2Cf17%2Cf18%2Cf15%2Cf16&fid=f3&pn=1&pz=100&po=1&dect=1&wbp2u=%7C0%7C0%7C0%7Cweb (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))

# %% [markdown]
# ## 6. 指数相关模型 (Index Models)
# ### 6.1 Available Indices (可用指数)

# %%
obb.index.available(provider=provider).to_dataframe().head()
# Out:
#    symbol  name currency publish_date
# 0  000001  上证指数      CNY   1991-07-15
# 1  000002  A股指数      CNY   1992-02-21
# 2  000003  B股指数      CNY   1992-02-21
# 3  000004  工业指数      CNY   1993-05-03
# 4  000005  商业指数      CNY   1993-05-03
